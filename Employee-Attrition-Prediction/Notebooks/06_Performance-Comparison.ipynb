# %%
# %pip install -r requirements.txt
import joblib
# Out:
# Requirement already satisfied: numpy in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 1)) (2.2.6)
# Requirement already satisfied: pandas in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: matplotlib in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 3)) (3.10.3)
# Requirement already satisfied: seaborn in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 5)) (1.7.0)
# Requirement already satisfied: xgboost in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 6)) (3.0.2)
# Collecting shap (from -r requirements.txt (line 7))
#   Using cached shap-0.47.2.tar.gz (2.6 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: joblib in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 8)) (1.5.1)
# Collecting streamlit (from -r requirements.txt (line 9))
#   Using cached streamlit-1.45.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting gradio (from -r requirements.txt (line 10))
#   Using cached gradio-5.33.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: jupyterlab in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 11)) (4.4.3)
# Requirement already satisfied: pyod in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 12)) (2.0.5)
# Requirement already satisfied: missingno in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 13)) (0.5.2)
# Requirement already satisfied: ipywidgets in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from -r requirements.txt (line 14)) (8.1.7)
# Collecting voila (from -r requirements.txt (line 15))
#   Using cached voila-0.5.8-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from pandas->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r requirements.txt (line 2)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from matplotlib->-r requirements.txt (line 3)) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r requirements.txt (line 3)) (3.2.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->-r requirements.txt (line 5)) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->-r requirements.txt (line 5)) (3.6.0)
# Collecting tqdm>=4.27.0 (from shap->-r requirements.txt (line 7))
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting slicer==0.0.8 (from shap->-r requirements.txt (line 7))
#   Using cached slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numba>=0.54 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from shap->-r requirements.txt (line 7)) (0.61.2)
# Collecting cloudpickle (from shap->-r requirements.txt (line 7))
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from shap->-r requirements.txt (line 7)) (4.14.0)
# Collecting altair<6,>=4.0 (from streamlit->-r requirements.txt (line 9))
#   Using cached altair-5.5.0-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit->-r requirements.txt (line 9))
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<6,>=4.0 (from streamlit->-r requirements.txt (line 9))
#   Using cached cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting click<9,>=7.0 (from streamlit->-r requirements.txt (line 9))
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting packaging>=20.0 (from matplotlib->-r requirements.txt (line 3))
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting protobuf<7,>=3.20 (from streamlit->-r requirements.txt (line 9))
#   Using cached protobuf-6.31.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting pyarrow>=7.0 (from streamlit->-r requirements.txt (line 9))
#   Using cached pyarrow-20.0.0-cp313-cp313-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from streamlit->-r requirements.txt (line 9)) (2.32.3)
# Collecting tenacity<10,>=8.1.0 (from streamlit->-r requirements.txt (line 9))
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit->-r requirements.txt (line 9))
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting watchdog<7,>=2.1.5 (from streamlit->-r requirements.txt (line 9))
#   Using cached watchdog-6.0.0-py3-none-win_amd64.whl.metadata (44 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit->-r requirements.txt (line 9))
#   Using cached GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit->-r requirements.txt (line 9))
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from streamlit->-r requirements.txt (line 9)) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 9)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 9)) (4.24.0)
# Collecting narwhals>=1.14.2 (from altair<6,>=4.0->streamlit->-r requirements.txt (line 9))
#   Using cached narwhals-1.42.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: colorama in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from click<9,>=7.0->streamlit->-r requirements.txt (line 9)) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 9))
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 9))
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 9)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 9)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 9)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 9)) (2025.4.26)
# Collecting aiofiles<25.0,>=22.0 (from gradio->-r requirements.txt (line 10))
#   Using cached aiofiles-24.1.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 10)) (4.9.0)
# Collecting audioop-lts<1.0 (from gradio->-r requirements.txt (line 10))
#   Using cached audioop_lts-0.2.1-cp313-abi3-win_amd64.whl.metadata (1.7 kB)
# Collecting fastapi<1.0,>=0.115.2 (from gradio->-r requirements.txt (line 10))
#   Using cached fastapi-0.115.12-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy (from gradio->-r requirements.txt (line 10))
#   Using cached ffmpy-0.6.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting gradio-client==1.10.3 (from gradio->-r requirements.txt (line 10))
#   Using cached gradio_client-1.10.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy~=0.1 (from gradio->-r requirements.txt (line 10))
#   Using cached groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 10)) (0.28.1)
# Collecting huggingface-hub>=0.28.1 (from gradio->-r requirements.txt (line 10))
#   Using cached huggingface_hub-0.32.5-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 10)) (3.0.2)
# Collecting orjson~=3.0 (from gradio->-r requirements.txt (line 10))
#   Using cached orjson-3.10.18-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Collecting pydantic<2.12,>=2.0 (from gradio->-r requirements.txt (line 10))
#   Using cached pydantic-2.11.5-py3-none-any.whl.metadata (67 kB)
# Collecting pydub (from gradio->-r requirements.txt (line 10))
#   Using cached pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.18 (from gradio->-r requirements.txt (line 10))
#   Using cached python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from gradio->-r requirements.txt (line 10)) (6.0.2)
# Collecting ruff>=0.9.3 (from gradio->-r requirements.txt (line 10))
#   Using cached ruff-0.11.13-py3-none-win_amd64.whl.metadata (26 kB)
# Collecting safehttpx<0.2.0,>=0.1.6 (from gradio->-r requirements.txt (line 10))
#   Using cached safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting semantic-version~=2.0 (from gradio->-r requirements.txt (line 10))
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting starlette<1.0,>=0.40.0 (from gradio->-r requirements.txt (line 10))
#   Using cached starlette-0.47.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting tomlkit<0.14.0,>=0.12.0 (from gradio->-r requirements.txt (line 10))
#   Using cached tomlkit-0.13.3-py3-none-any.whl.metadata (2.8 kB)
# Collecting typer<1.0,>=0.12 (from gradio->-r requirements.txt (line 10))
#   Using cached typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Collecting uvicorn>=0.14.0 (from gradio->-r requirements.txt (line 10))
#   Using cached uvicorn-0.34.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting fsspec (from gradio-client==1.10.3->gradio->-r requirements.txt (line 10))
#   Using cached fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Collecting websockets<16.0,>=10.0 (from gradio-client==1.10.3->gradio->-r requirements.txt (line 10))
#   Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0,>=3.0->gradio->-r requirements.txt (line 10)) (1.3.1)
# Collecting starlette<1.0,>=0.40.0 (from gradio->-r requirements.txt (line 10))
#   Using cached starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<2.12,>=2.0->gradio->-r requirements.txt (line 10))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<2.12,>=2.0->gradio->-r requirements.txt (line 10))
#   Using cached pydantic_core-2.33.2-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<2.12,>=2.0->gradio->-r requirements.txt (line 10))
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 10))
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0,>=0.12->gradio->-r requirements.txt (line 10))
#   Using cached rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r requirements.txt (line 11)) (2.0.5)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from jupyterlab->-r requirements.txt (line 11)) (6.29.5)
# Requirement already satisfied: jupyter-core in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from jupyterlab->-r requirements.txt (line 11)) (5.8.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r requirements.txt (line 11)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r requirements.txt (line 11)) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r requirements.txt (line 11)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r requirements.txt (line 11)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab->-r requirements.txt (line 11)) (80.9.0)
# Requirement already satisfied: traitlets in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from jupyterlab->-r requirements.txt (line 11)) (5.14.3)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (26.4.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 11)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->-r requirements.txt (line 11)) (0.12.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from ipywidgets->-r requirements.txt (line 14)) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from ipywidgets->-r requirements.txt (line 14)) (9.3.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets->-r requirements.txt (line 14)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets->-r requirements.txt (line 14)) (3.0.15)
# Requirement already satisfied: nbclient>=0.4.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from voila->-r requirements.txt (line 15)) (0.10.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (3.1.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (2.19.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (21.2.0)
# Requirement already satisfied: webencodings in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.24.1->gradio->-r requirements.txt (line 10)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio->-r requirements.txt (line 10)) (0.16.0)
# Collecting filelock (from huggingface-hub>=0.28.1->gradio->-r requirements.txt (line 10))
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 11)) (1.8.14)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 11)) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 11)) (1.6.0)
# Requirement already satisfied: psutil in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from ipykernel>=6.5.0->jupyterlab->-r requirements.txt (line 11)) (7.0.0)
# Requirement already satisfied: decorator in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 14)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 14)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 14)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 14)) (3.0.51)
# Requirement already satisfied: stack_data in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 14)) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 14)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 14)) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 9)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 9)) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 9)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 9)) (0.25.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from jupyter-core->jupyterlab->-r requirements.txt (line 11)) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from jupyter-core->jupyterlab->-r requirements.txt (line 11)) (310)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (3.3.0)
# Requirement already satisfied: rfc3339-validator in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (24.11.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (2.21.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from numba>=0.54->shap->-r requirements.txt (line 7)) (0.44.0)
# Requirement already satisfied: six>=1.5 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 2)) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 10))
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->-r requirements.txt (line 10))
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (2.22)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (2.7)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\ishaan.narayan\appdata\local\programs\python\python313\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->-r requirements.txt (line 11)) (2.9.0.20250516)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 14)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 14)) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\ishaan.narayan\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 14)) (0.2.3)
# Using cached slicer-0.0.8-py3-none-any.whl (15 kB)
# Using cached streamlit-1.45.1-py3-none-any.whl (9.9 MB)
# Using cached altair-5.5.0-py3-none-any.whl (731 kB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached cachetools-5.5.2-py3-none-any.whl (10 kB)
# Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Using cached protobuf-6.31.1-cp310-abi3-win_amd64.whl (435 kB)
# Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached watchdog-6.0.0-py3-none-win_amd64.whl (79 kB)
# Using cached gradio-5.33.1-py3-none-any.whl (54.2 MB)
# Using cached gradio_client-1.10.3-py3-none-any.whl (323 kB)
# Using cached aiofiles-24.1.0-py3-none-any.whl (15 kB)
# Using cached audioop_lts-0.2.1-cp313-abi3-win_amd64.whl (30 kB)
# Using cached fastapi-0.115.12-py3-none-any.whl (95 kB)
# Using cached groovy-0.1.2-py3-none-any.whl (14 kB)
# Using cached orjson-3.10.18-cp313-cp313-win_amd64.whl (134 kB)
# Using cached pydantic-2.11.5-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp313-cp313-win_amd64.whl (2.0 MB)
# Using cached safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Using cached starlette-0.46.2-py3-none-any.whl (72 kB)
# Using cached tomlkit-0.13.3-py3-none-any.whl (38 kB)
# Using cached typer-0.16.0-py3-none-any.whl (46 kB)
# Using cached websockets-15.0.1-cp313-cp313-win_amd64.whl (176 kB)
# Using cached voila-0.5.8-py3-none-any.whl (4.5 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached huggingface_hub-0.32.5-py3-none-any.whl (512 kB)
# Using cached fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Using cached narwhals-1.42.0-py3-none-any.whl (359 kB)
# Using cached pyarrow-20.0.0-cp313-cp313-win_amd64.whl (25.7 MB)
# Using cached python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Using cached rich-14.0.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached ruff-0.11.13-py3-none-win_amd64.whl (11.5 MB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached uvicorn-0.34.3-py3-none-any.whl (62 kB)
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Using cached ffmpy-0.6.0-py3-none-any.whl (5.5 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Building wheels for collected packages: shap
#   Building wheel for shap (pyproject.toml): started
#   Building wheel for shap (pyproject.toml): finished with status 'error'
# Failed to build shap
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for shap (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [260 lines of output]
#       Attempting to build SHAP: with_binary=True, with_cuda=True (Attempt 1)
#       The nvcc binary could not be located in your $PATH. Either add it to your path, or set $CUDAHOME to enable CUDA.
#       Exception occurred during setup, Error building cuda module: TypeError('cannot unpack non-iterable NoneType object')
#       WARNING: Could not compile cuda extensions.
#       Retrying SHAP build without cuda extension...
#       Attempting to build SHAP: with_binary=True, with_cuda=False (Attempt 2)
#       C:\Users\ishaan.narayan\AppData\Local\Temp\pip-build-env-bfyzk15j\overlay\Lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:82: SetuptoolsDeprecationWarning: `project.license` as a TOML table is deprecated
#       !!
#
#               ********************************************************************************
#               Please use a simple string containing a SPDX expression for `project.license`. You can also use `project.license-files`. (Both options available on setuptools>=77.0.0).
#
#               By 2026-Feb-18, you need to update your project and remove deprecated calls
#               or your builds will no longer be supported.
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         corresp(dist, value, root_dir)
#       C:\Users\ishaan.narayan\AppData\Local\Temp\pip-build-env-bfyzk15j\overlay\Lib\site-packages\setuptools\config\_apply_pyprojecttoml.py:61: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: MIT License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         dist._finalize_license_expression()
#       C:\Users\ishaan.narayan\AppData\Local\Temp\pip-build-env-bfyzk15j\overlay\Lib\site-packages\setuptools\dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: MIT License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-313\shap
#       copying shap\datasets.py -> build\lib.win-amd64-cpython-313\shap
#       copying shap\links.py -> build\lib.win-amd64-cpython-313\shap
#       copying shap\_explanation.py -> build\lib.win-amd64-cpython-313\shap
#       copying shap\_serializable.py -> build\lib.win-amd64-cpython-313\shap
#       copying shap\_version.py -> build\lib.win-amd64-cpython-313\shap
#       copying shap\__init__.py -> build\lib.win-amd64-cpython-313\shap
#       creating build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\explainers\pytree.py -> build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\explainers\tf_utils.py -> build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\explainers\_additive.py -> build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\explainers\_exact.py -> build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\explainers\_explainer.py -> build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\explainers\_gpu_tree.py -> build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\explainers\_gradient.py -> build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\explainers\_kernel.py -> build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\explainers\_linear.py -> build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\explainers\_partition.py -> build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\explainers\_permutation.py -> build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\explainers\_sampling.py -> build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\explainers\_tree.py -> build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\explainers\__init__.py -> build\lib.win-amd64-cpython-313\shap\explainers
#       creating build\lib.win-amd64-cpython-313\shap\explainers\other
#       copying shap\explainers\other\_coefficient.py -> build\lib.win-amd64-cpython-313\shap\explainers\other
#       copying shap\explainers\other\_lime.py -> build\lib.win-amd64-cpython-313\shap\explainers\other
#       copying shap\explainers\other\_maple.py -> build\lib.win-amd64-cpython-313\shap\explainers\other
#       copying shap\explainers\other\_random.py -> build\lib.win-amd64-cpython-313\shap\explainers\other
#       copying shap\explainers\other\_treegain.py -> build\lib.win-amd64-cpython-313\shap\explainers\other
#       copying shap\explainers\other\_ubjson.py -> build\lib.win-amd64-cpython-313\shap\explainers\other
#       copying shap\explainers\other\__init__.py -> build\lib.win-amd64-cpython-313\shap\explainers\other
#       creating build\lib.win-amd64-cpython-313\shap\explainers\_deep
#       copying shap\explainers\_deep\deep_pytorch.py -> build\lib.win-amd64-cpython-313\shap\explainers\_deep
#       copying shap\explainers\_deep\deep_tf.py -> build\lib.win-amd64-cpython-313\shap\explainers\_deep
#       copying shap\explainers\_deep\deep_utils.py -> build\lib.win-amd64-cpython-313\shap\explainers\_deep
#       copying shap\explainers\_deep\__init__.py -> build\lib.win-amd64-cpython-313\shap\explainers\_deep
#       creating build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_bar.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_beeswarm.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_benchmark.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_decision.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_embedding.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_force.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_force_matplotlib.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_group_difference.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_heatmap.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_image.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_labels.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_monitoring.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_partial_dependence.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_scatter.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_style.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_text.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_utils.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_violin.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\_waterfall.py -> build\lib.win-amd64-cpython-313\shap\plots
#       copying shap\plots\__init__.py -> build\lib.win-amd64-cpython-313\shap\plots
#       creating build\lib.win-amd64-cpython-313\shap\plots\colors
#       copying shap\plots\colors\_colorconv.py -> build\lib.win-amd64-cpython-313\shap\plots\colors
#       copying shap\plots\colors\_colors.py -> build\lib.win-amd64-cpython-313\shap\plots\colors
#       copying shap\plots\colors\__init__.py -> build\lib.win-amd64-cpython-313\shap\plots\colors
#       creating build\lib.win-amd64-cpython-313\shap\benchmark
#       copying shap\benchmark\experiments.py -> build\lib.win-amd64-cpython-313\shap\benchmark
#       copying shap\benchmark\framework.py -> build\lib.win-amd64-cpython-313\shap\benchmark
#       copying shap\benchmark\measures.py -> build\lib.win-amd64-cpython-313\shap\benchmark
#       copying shap\benchmark\methods.py -> build\lib.win-amd64-cpython-313\shap\benchmark
#       copying shap\benchmark\metrics.py -> build\lib.win-amd64-cpython-313\shap\benchmark
#       copying shap\benchmark\models.py -> build\lib.win-amd64-cpython-313\shap\benchmark
#       copying shap\benchmark\plots.py -> build\lib.win-amd64-cpython-313\shap\benchmark
#       copying shap\benchmark\_compute.py -> build\lib.win-amd64-cpython-313\shap\benchmark
#       copying shap\benchmark\_explanation_error.py -> build\lib.win-amd64-cpython-313\shap\benchmark
#       copying shap\benchmark\_result.py -> build\lib.win-amd64-cpython-313\shap\benchmark
#       copying shap\benchmark\_sequential.py -> build\lib.win-amd64-cpython-313\shap\benchmark
#       copying shap\benchmark\__init__.py -> build\lib.win-amd64-cpython-313\shap\benchmark
#       creating build\lib.win-amd64-cpython-313\shap\maskers
#       copying shap\maskers\_composite.py -> build\lib.win-amd64-cpython-313\shap\maskers
#       copying shap\maskers\_fixed.py -> build\lib.win-amd64-cpython-313\shap\maskers
#       copying shap\maskers\_fixed_composite.py -> build\lib.win-amd64-cpython-313\shap\maskers
#       copying shap\maskers\_image.py -> build\lib.win-amd64-cpython-313\shap\maskers
#       copying shap\maskers\_masker.py -> build\lib.win-amd64-cpython-313\shap\maskers
#       copying shap\maskers\_output_composite.py -> build\lib.win-amd64-cpython-313\shap\maskers
#       copying shap\maskers\_tabular.py -> build\lib.win-amd64-cpython-313\shap\maskers
#       copying shap\maskers\_text.py -> build\lib.win-amd64-cpython-313\shap\maskers
#       copying shap\maskers\__init__.py -> build\lib.win-amd64-cpython-313\shap\maskers
#       creating build\lib.win-amd64-cpython-313\shap\utils
#       copying shap\utils\image.py -> build\lib.win-amd64-cpython-313\shap\utils
#       copying shap\utils\transformers.py -> build\lib.win-amd64-cpython-313\shap\utils
#       copying shap\utils\_clustering.py -> build\lib.win-amd64-cpython-313\shap\utils
#       copying shap\utils\_exceptions.py -> build\lib.win-amd64-cpython-313\shap\utils
#       copying shap\utils\_general.py -> build\lib.win-amd64-cpython-313\shap\utils
#       copying shap\utils\_keras.py -> build\lib.win-amd64-cpython-313\shap\utils
#       copying shap\utils\_legacy.py -> build\lib.win-amd64-cpython-313\shap\utils
#       copying shap\utils\_masked_model.py -> build\lib.win-amd64-cpython-313\shap\utils
#       copying shap\utils\_show_progress.py -> build\lib.win-amd64-cpython-313\shap\utils
#       copying shap\utils\_types.py -> build\lib.win-amd64-cpython-313\shap\utils
#       copying shap\utils\_warnings.py -> build\lib.win-amd64-cpython-313\shap\utils
#       copying shap\utils\__init__.py -> build\lib.win-amd64-cpython-313\shap\utils
#       creating build\lib.win-amd64-cpython-313\shap\actions
#       copying shap\actions\_action.py -> build\lib.win-amd64-cpython-313\shap\actions
#       copying shap\actions\_optimizer.py -> build\lib.win-amd64-cpython-313\shap\actions
#       copying shap\actions\__init__.py -> build\lib.win-amd64-cpython-313\shap\actions
#       creating build\lib.win-amd64-cpython-313\shap\models
#       copying shap\models\_model.py -> build\lib.win-amd64-cpython-313\shap\models
#       copying shap\models\_teacher_forcing.py -> build\lib.win-amd64-cpython-313\shap\models
#       copying shap\models\_text_generation.py -> build\lib.win-amd64-cpython-313\shap\models
#       copying shap\models\_topk_lm.py -> build\lib.win-amd64-cpython-313\shap\models
#       copying shap\models\_transformers_pipeline.py -> build\lib.win-amd64-cpython-313\shap\models
#       copying shap\models\__init__.py -> build\lib.win-amd64-cpython-313\shap\models
#       running egg_info
#       writing shap.egg-info\PKG-INFO
#       writing dependency_links to shap.egg-info\dependency_links.txt
#       writing requirements to shap.egg-info\requires.txt
#       writing top-level names to shap.egg-info\top_level.txt
#       ERROR setuptools_scm._file_finders.git listing git files failed - pretending there aren't any
#       reading manifest file 'shap.egg-info\SOURCES.txt'
#       adding license file 'LICENSE'
#       writing manifest file 'shap.egg-info\SOURCES.txt'
#       C:\Users\ishaan.narayan\AppData\Local\Temp\pip-build-env-bfyzk15j\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'shap.cext' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'shap.cext' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'shap.cext' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'shap.cext' to be distributed and are
#               already explicitly excluding 'shap.cext' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\ishaan.narayan\AppData\Local\Temp\pip-build-env-bfyzk15j\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'shap.explainers' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'shap.explainers' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'shap.explainers' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'shap.explainers' to be distributed and are
#               already explicitly excluding 'shap.explainers' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       creating build\lib.win-amd64-cpython-313\shap\cext
#       copying shap\cext\_cext.cc -> build\lib.win-amd64-cpython-313\shap\cext
#       copying shap\explainers\_kernel_lib.pyx -> build\lib.win-amd64-cpython-313\shap\explainers
#       copying shap\cext\_cext_gpu.cc -> build\lib.win-amd64-cpython-313\shap\cext
#       copying shap\cext\_cext_gpu.cu -> build\lib.win-amd64-cpython-313\shap\cext
#       copying shap\cext\gpu_treeshap.h -> build\lib.win-amd64-cpython-313\shap\cext
#       copying shap\cext\tree_shap.h -> build\lib.win-amd64-cpython-313\shap\cext
#       creating build\lib.win-amd64-cpython-313\shap\plots\resources
#       copying shap\plots\resources\bundle.js -> build\lib.win-amd64-cpython-313\shap\plots\resources
#       copying shap\plots\resources\logoSmallGray.png -> build\lib.win-amd64-cpython-313\shap\plots\resources
#       running build_ext
#       building 'shap._cext' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for shap
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (shap)

# %%
#lets load The model 
randomForest_model = joblib.load(r"C:\Users\ishaan.narayan\Desktop\Ishaan's Workspace\Intern_ML-DL-Gen\Employee-Attrition-Prediction\Models\best_rf_model.pkl")
XGB_model = joblib.load(r"C:\Users\ishaan.narayan\Desktop\Ishaan's Workspace\Intern_ML-DL-Gen\Employee-Attrition-Prediction\Models\best_model_XGB.pkl")
print(randomForest_model)
print(XGB_model)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_split=5, n_estimators=200,
#                        random_state=42)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"C:\Users\ishaan.narayan\Desktop\Ishaan's Workspace\Intern_ML-DL-Gen\Employee-Attrition-Prediction\Data\cleaned_employee_data.csv")
print(df.columns)
# Out:
# Index(['Age', 'Attrition', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely',
#        'Department_Research & Development', 'Department_Sales',
#        'EducationField_Life Sciences', 'EducationField_Marketing',
#        'EducationField_Medical', 'EducationField_Other',
#        'EducationField_Technical Degree', 'Gender_Male',
#        'JobRole_Human Resources', 'JobRole_Laboratory Technician',
#        'JobRole_Manager', 'JobRole_Manufacturing Director',
#        'JobRole_Research Director', 'JobRole_Research Scientist',
#        'JobRole_Sales Executive', 'JobRole_Sales Representative',
#        'MaritalStatus_Married', 'MaritalStatus_Single', 'OverTime_Yes'],
#       dtype='object')

# %%
#starting with the FrontEnd UI part

# %%
import ipywidgets as widgets
from IPython.display import display , clear_output

# %%
#mentioning the features that are to be used 
jobroles = ["Human Resources", "Laboratory Technician", "Manager", "Manufacturing Director",
    "Research Director", "Research Scientist", "Sales Executive",
    "Sales Representative", "Healthcare Representative"]

businesstravel = ["Travel_Rarely", "Travel_Frequently", "Non-Travel"]
maritalstatus = ["Single", "Married", "Divorced"]
overtime = ["Yes", "No"]

# %%
## for all the features that need to be shown on the WEBAPP
# also How they will be Shown to the User ? 
#as a dropdown or ? slider ? or text BOX

age = widgets.IntSlider(description='Age', min=18, max=60, value=30)

monthly_income = widgets.IntText(description='MonthlyIncome', value=5000)

jobsatisfaction = widgets.Dropdown(description='JobSatisfaction', options=[1,2,3,4], value=3)

overtime_yes = widgets.Dropdown(description='OverTime', options=overtime, value="No")

total_work_years = widgets.IntSlider(description='TotalWorkingYrs', min=0, max=40, value=10)

years_at_company = widgets.IntSlider(description='YrsAtCompany', min=0, max=40, value=5)

jobrole = widgets.Dropdown(description='JobRole', options=jobroles, value=jobroles[0])

bus_travel = widgets.Dropdown(description='BusinessTravel', options=businesstravel, value=businesstravel[0])

marital_status = widgets.Dropdown(description='MaritalStatus', options=maritalstatus, value=maritalstatus[0])

distance_home = widgets.IntSlider(description='DistFromHome', min=1, max=30, value=5)

submit_button = widgets.Button(description="Predict Attrition")

# %%
result_out = widgets.Output()
feat_out = widgets.Output()
